# %%
import uproot
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import math
from scipy.fft import fft, fftfreq
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import os
from plotly.subplots import make_subplots
from plotly import tools
import plotly.offline as pyo
import sys

# %%
HV_dict = {'Run':[],'HV':[],'Mean RMS': [], 'Median RMS': []}
Run_list = [14421,14344,14329,14275,14218,14214,14192,14191,14177]
HV_list = [100,95,90,78,53,45,40,35,30]
HV_dict['Run']=Run_list
HV_dict['HV']=HV_list
print(HV_dict)
# Out:
# {'Run': [14421, 14344, 14329, 14275, 14218, 14214, 14192, 14191, 14177], 'HV': [100, 95, 90, 78, 53, 45, 40, 35, 30], 'Mean RMS': [], 'Median RMS': []}

# %%
for runs in HV_dict['Run']:
    print(runs)
    file =uproot.open(f"/Users/danielcarber/Documents/SBND/Noise Analysis/data/noise_output_run{runs}.root")
    raw_rms = file['tpc_noise;1']['raw_rms'].array().to_list()
    if runs == 14177:
        print(raw_rms)
    print(np.mean(raw_rms))
# Out:
# 14421
# 1.968905687723732
# 14344
# 1.9701613179323347
# 14329
# 1.9801237735770305
# 14275
# 1.9732131371486255
# 14218
# 1.9686227363682436
# 14214
# 1.9657768354200842
# 14192
# 1.9657768354200842
# 14191
# 1.9657768354200842
# 14177
# ...
